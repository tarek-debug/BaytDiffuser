# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
import tensorflow as tf
# Out:
# 2024-12-31 15:14:58.303420: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-31 15:14:58.303517: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-31 15:14:58.304775: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-31 15:14:58.314242: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import sys
import os

# Add the scripts folder to the system path
scripts_path = os.path.abspath(os.path.join('..', 'scripts/python'))
sys.path.append(scripts_path)

# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from utils import (
    create_diffusion_model,
    train_diffusion_model,
    create_transformer_model,
    train_transformer_model,
    string_with_tashkeel_vectorizer_per_batch,
    calculate_meter_accuracy
)

# Configure visualization settings
# %matplotlib inline

# %%
# Paths
processed_data_path = '../data/processed/processed_taweel_data.csv'
diffusion_output_dir = '../models/diffusion'
transformer_output_dir = '../models/transformers'
os.makedirs(diffusion_output_dir, exist_ok=True)
os.makedirs(transformer_output_dir, exist_ok=True)

# Load processed data
print("Loading processed data...")
processed_df = pd.read_csv(processed_data_path, encoding='utf-8-sig')
print(f"Processed data loaded with {len(processed_df)} records.")

# For testing, use a subset or full dataset
subset = True  # Toggle this for subset testing or full dataset training
if subset:
    print("Using subset for testing...")
    train_df, valid_df = train_test_split(processed_df, test_size=0.2, random_state=42)
    train_subset = train_df.sample(n=100, random_state=42)  # Adjust as needed
    valid_subset = valid_df.sample(n=20, random_state=42)
else:
    train_df, valid_df = train_test_split(processed_df, test_size=0.2, random_state=42)
    train_subset, valid_subset = train_df, valid_df

print(f"Training records: {len(train_subset)}; Validation records: {len(valid_subset)}")
# Out:
# Loading processed data...
# Processed data loaded with 103441 records.
# Using subset for testing...
# Training records: 100; Validation records: 20

# %%
# Define model parameters
diffusion_model_params = {
    'num_transformer_blocks': 4,
    'num_heads': 8,
    'key_dim': 64,
    'ffn_units': 512
}

# Input shape
max_bayt_len = 1000  # Matches preprocessing
encoding_dim = 8
input_shape = (max_bayt_len, encoding_dim)

# %%
# =============================================================================
# Diffusion Model
# =============================================================================

print("Creating diffusion model...")
diffusion_model = create_diffusion_model(input_shape, diffusion_model_params)

# Prepare data
X_train = train_subset['text'].tolist()
Y_train = X_train.copy()  # Target is clean data

X_valid = valid_subset['text'].tolist()
Y_valid = X_valid.copy()

# Vectorize data
print("Vectorizing training and validation data...")
X_train_enc = string_with_tashkeel_vectorizer_per_batch(pd.Series(X_train), max_bayt_len)
Y_train_enc = string_with_tashkeel_vectorizer_per_batch(pd.Series(Y_train), max_bayt_len)
X_valid_enc = string_with_tashkeel_vectorizer_per_batch(pd.Series(X_valid), max_bayt_len)
Y_valid_enc = string_with_tashkeel_vectorizer_per_batch(pd.Series(Y_valid), max_bayt_len)

# Train diffusion model
print("Training diffusion model...")
diffusion_history = diffusion_model.fit(
    X_train_enc, Y_train_enc,
    validation_data=(X_valid_enc, Y_valid_enc),
    epochs=50,
    batch_size=32,
    verbose=1
)

# Save diffusion model
diffusion_final_path = os.path.join(diffusion_output_dir, 'diffusion_model_taweel_final.h5')
diffusion_model.save(diffusion_final_path)
print(f"Diffusion model saved to {diffusion_final_path}")
# Out:
# Creating diffusion model...
# 2024-12-31 15:16:40.482471: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-31 15:16:40.840986: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-31 15:16:40.841199: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-31 15:16:40.852375: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-31 15:16:40.852920: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-31 15:16:40.853068: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-31 15:16:41.337856: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-31 15:16:41.338782: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-31 15:16:41.338818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-12-31 15:16:41.338911: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-31 15:16:41.339389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5582 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "DiffusionModel"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 1000, 8)]            0         []
#
#  layer_normalization (Layer  (None, 1000, 8)              16        ['input_layer[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 1000, 8)              17928     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 1000, 8)              0         ['layer_normalization[0][0]',
#                                                                      'multi_head_attention[0][0]']
#
#  layer_normalization_1 (Lay  (None, 1000, 8)              16        ['add[0][0]']
#  erNormalization)
#
#  sequential (Sequential)     (None, 1000, 8)              8712      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 1000, 8)              0         ['layer_normalization_1[0][0]'
#                                                                     , 'sequential[0][0]']
#
#  layer_normalization_2 (Lay  (None, 1000, 8)              16        ['add_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 1000, 8)              17928     ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 1000, 8)              0         ['layer_normalization_2[0][0]'
#                                                                     , 'multi_head_attention_1[0][0
#                                                                     ]']
#
#  layer_normalization_3 (Lay  (None, 1000, 8)              16        ['add_2[0][0]']
#  erNormalization)
#
#  sequential_1 (Sequential)   (None, 1000, 8)              8712      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  add_3 (Add)                 (None, 1000, 8)              0         ['layer_normalization_3[0][0]'
#                                                                     , 'sequential_1[0][0]']
#
#  layer_normalization_4 (Lay  (None, 1000, 8)              16        ['add_3[0][0]']
#  erNormalization)
#
#  multi_head_attention_2 (Mu  (None, 1000, 8)              17928     ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 1000, 8)              0         ['layer_normalization_4[0][0]'
#                                                                     , 'multi_head_attention_2[0][0
#                                                                     ]']
#
#  layer_normalization_5 (Lay  (None, 1000, 8)              16        ['add_4[0][0]']
#  erNormalization)
#
#  sequential_2 (Sequential)   (None, 1000, 8)              8712      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  add_5 (Add)                 (None, 1000, 8)              0         ['layer_normalization_5[0][0]'
#                                                                     , 'sequential_2[0][0]']
#
#  layer_normalization_6 (Lay  (None, 1000, 8)              16        ['add_5[0][0]']
#  erNormalization)
#
#  multi_head_attention_3 (Mu  (None, 1000, 8)              17928     ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 1000, 8)              0         ['layer_normalization_6[0][0]'
#                                                                     , 'multi_head_attention_3[0][0
#                                                                     ]']
#
#  layer_normalization_7 (Lay  (None, 1000, 8)              16        ['add_6[0][0]']
#  erNormalization)
#
#  sequential_3 (Sequential)   (None, 1000, 8)              8712      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  add_7 (Add)                 (None, 1000, 8)              0         ['layer_normalization_7[0][0]'
#                                                                     , 'sequential_3[0][0]']
#
#  layer_normalization_8 (Lay  (None, 1000, 8)              16        ['add_7[0][0]']
#  erNormalization)
#
#  output_layer (Dense)        (None, 1000, 8)              72        ['layer_normalization_8[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 106776 (417.09 KB)
# Trainable params: 106776 (417.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Vectorizing training and validation data...
# Training diffusion model...
# Epoch 1/50
# 2024-12-31 15:16:49.968899: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-12-31 15:17:00.725506: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 976.56MiB (rounded to 1024000000)requested by op DiffusionModel/multi_head_attention_2/softmax/Softmax
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-12-31 15:17:00.725623: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-12-31 15:17:00.725641: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 114, Chunks in use: 113. 28.5KiB allocated for chunks. 28.2KiB in use in bin. 3.4KiB client-requested in use in bin.
# 2024-12-31 15:17:00.725648: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 1, Chunks in use: 0. 512B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725654: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2024-12-31 15:17:00.725660: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 48, Chunks in use: 48. 97.8KiB allocated for chunks. 97.8KiB in use in bin. 96.0KiB client-requested in use in bin.
# 2024-12-31 15:17:00.725668: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725673: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725678: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 72, Chunks in use: 72. 1.14MiB allocated for chunks. 1.14MiB in use in bin. 1.12MiB client-requested in use in bin.
# 2024-12-31 15:17:00.725683: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725688: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 13, Chunks in use: 12. 1.59MiB allocated for chunks. 1.46MiB in use in bin. 1.46MiB client-requested in use in bin.
# 2024-12-31 15:17:00.725694: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 1, Chunks in use: 0. 250.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725698: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725704: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 14, Chunks in use: 14. 13.67MiB allocated for chunks. 13.67MiB in use in bin. 13.67MiB client-requested in use in bin.
# 2024-12-31 15:17:00.725710: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.95MiB allocated for chunks. 1.95MiB in use in bin. 1000.0KiB client-requested in use in bin.
# 2024-12-31 15:17:00.725714: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725719: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725723: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725743: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725749: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 11, Chunks in use: 11. 687.50MiB allocated for chunks. 687.50MiB in use in bin. 687.50MiB client-requested in use in bin.
# 2024-12-31 15:17:00.725756: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 2, Chunks in use: 2. 243.04MiB allocated for chunks. 243.04MiB in use in bin. 125.00MiB client-requested in use in bin.
# 2024-12-31 15:17:00.725760: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-31 15:17:00.725766: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 6, Chunks in use: 4. 4.52GiB allocated for chunks. 3.81GiB in use in bin. 3.81GiB client-requested in use in bin.
# 2024-12-31 15:17:00.725772: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 976.56MiB was 256.00MiB, Chunk State:
# 2024-12-31 15:17:00.725785: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 344.97MiB | Requested Size: 62.50MiB | in_use: 0 | bin_num: 20, prev:   Size: 62.50MiB | Requested Size: 62.50MiB | in_use: 1 | bin_num: -1, next:   Size: 976.56MiB | Requested Size: 976.56MiB | in_use: 1 | bin_num: -1
# 2024-12-31 15:17:00.725792: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 381.52MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 976.56MiB | Requested Size: 976.56MiB | in_use: 1 | bin_num: -1
# 2024-12-31 15:17:00.725796: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 5853151232
# 2024-12-31 15:17:00.725802: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08200000 of size 1280 next 1
# 2024-12-31 15:17:00.725806: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08200500 of size 256 next 2
# 2024-12-31 15:17:00.725809: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08200600 of size 256 next 3
# 2024-12-31 15:17:00.725813: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08200700 of size 256 next 4
# 2024-12-31 15:17:00.725816: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08200800 of size 256 next 5
# 2024-12-31 15:17:00.725819: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08200900 of size 256 next 6
# 2024-12-31 15:17:00.725823: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08200a00 of size 256 next 7
# 2024-12-31 15:17:00.725826: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08200b00 of size 2048 next 9
# 2024-12-31 15:17:00.725830: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08201300 of size 31488 next 12
# 2024-12-31 15:17:00.725837: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08208e00 of size 16384 next 13
# 2024-12-31 15:17:00.725840: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820ce00 of size 2048 next 8
# 2024-12-31 15:17:00.725844: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820d600 of size 2048 next 10
# 2024-12-31 15:17:00.725847: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820de00 of size 256 next 11
# 2024-12-31 15:17:00.725850: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820df00 of size 256 next 18
# 2024-12-31 15:17:00.725854: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820e000 of size 256 next 20
# 2024-12-31 15:17:00.725857: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820e100 of size 256 next 21
# 2024-12-31 15:17:00.725860: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820e200 of size 256 next 22
# 2024-12-31 15:17:00.725864: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820e300 of size 256 next 23
# 2024-12-31 15:17:00.725867: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820e400 of size 2048 next 24
# 2024-12-31 15:17:00.725871: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820ec00 of size 256 next 25
# 2024-12-31 15:17:00.725874: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820ed00 of size 256 next 27
# 2024-12-31 15:17:00.725877: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820ee00 of size 256 next 29
# 2024-12-31 15:17:00.725881: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820ef00 of size 2048 next 30
# 2024-12-31 15:17:00.725884: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820f700 of size 2048 next 31
# 2024-12-31 15:17:00.725887: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0820ff00 of size 2048 next 33
# 2024-12-31 15:17:00.725891: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08210700 of size 256 next 35
# 2024-12-31 15:17:00.725894: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08210800 of size 256 next 37
# 2024-12-31 15:17:00.725897: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08210900 of size 256 next 39
# 2024-12-31 15:17:00.725901: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08210a00 of size 256 next 41
# 2024-12-31 15:17:00.725904: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08210b00 of size 256 next 43
# 2024-12-31 15:17:00.725907: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08210c00 of size 256 next 46
# 2024-12-31 15:17:00.725910: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08210d00 of size 256 next 53
# 2024-12-31 15:17:00.725914: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08210e00 of size 256 next 14
# 2024-12-31 15:17:00.725917: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08210f00 of size 16384 next 15
# 2024-12-31 15:17:00.725921: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08214f00 of size 2048 next 40
# 2024-12-31 15:17:00.725924: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08215700 of size 2048 next 47
# 2024-12-31 15:17:00.725927: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08215f00 of size 2048 next 49
# 2024-12-31 15:17:00.725931: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08216700 of size 2048 next 51
# 2024-12-31 15:17:00.725934: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08216f00 of size 256 next 55
# 2024-12-31 15:17:00.725937: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08217000 of size 2048 next 56
# 2024-12-31 15:17:00.725940: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08217800 of size 256 next 57
# 2024-12-31 15:17:00.725944: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08217900 of size 256 next 59
# 2024-12-31 15:17:00.725947: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08217a00 of size 256 next 61
# 2024-12-31 15:17:00.725950: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08217b00 of size 2048 next 62
# 2024-12-31 15:17:00.725954: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08218300 of size 3072 next 17
# 2024-12-31 15:17:00.725957: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08218f00 of size 16384 next 16
# 2024-12-31 15:17:00.725961: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0821cf00 of size 16384 next 19
# 2024-12-31 15:17:00.725964: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08220f00 of size 16384 next 26
# 2024-12-31 15:17:00.725967: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08224f00 of size 16384 next 28
# 2024-12-31 15:17:00.725971: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08228f00 of size 16384 next 32
# 2024-12-31 15:17:00.725974: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0822cf00 of size 16384 next 34
# 2024-12-31 15:17:00.725978: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08230f00 of size 16384 next 36
# 2024-12-31 15:17:00.725981: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08234f00 of size 16384 next 38
# 2024-12-31 15:17:00.725984: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08238f00 of size 16384 next 42
# 2024-12-31 15:17:00.725988: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823cf00 of size 2048 next 63
# 2024-12-31 15:17:00.725991: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823d700 of size 256 next 65
# 2024-12-31 15:17:00.725994: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823d800 of size 256 next 69
# 2024-12-31 15:17:00.725998: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823d900 of size 256 next 71
# 2024-12-31 15:17:00.726001: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823da00 of size 2048 next 72
# 2024-12-31 15:17:00.726005: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823e200 of size 256 next 73
# 2024-12-31 15:17:00.726008: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823e300 of size 256 next 75
# 2024-12-31 15:17:00.726011: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823e400 of size 256 next 77
# 2024-12-31 15:17:00.726015: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823e500 of size 256 next 78
# 2024-12-31 15:17:00.726018: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823e600 of size 256 next 79
# 2024-12-31 15:17:00.726021: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823e700 of size 256 next 81
# 2024-12-31 15:17:00.726025: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823e800 of size 256 next 80
# 2024-12-31 15:17:00.726028: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823e900 of size 256 next 82
# 2024-12-31 15:17:00.726031: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823ea00 of size 256 next 83
# 2024-12-31 15:17:00.726035: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823eb00 of size 256 next 84
# 2024-12-31 15:17:00.726038: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823ec00 of size 256 next 85
# 2024-12-31 15:17:00.726041: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823ed00 of size 256 next 86
# 2024-12-31 15:17:00.726044: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823ee00 of size 256 next 87
# 2024-12-31 15:17:00.726048: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823ef00 of size 256 next 88
# 2024-12-31 15:17:00.726051: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823f000 of size 256 next 89
# 2024-12-31 15:17:00.726055: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823f100 of size 256 next 90
# 2024-12-31 15:17:00.726058: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823f200 of size 256 next 91
# 2024-12-31 15:17:00.726061: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823f300 of size 256 next 92
# 2024-12-31 15:17:00.726064: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823f400 of size 2048 next 93
# 2024-12-31 15:17:00.726068: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0823fc00 of size 2048 next 94
# 2024-12-31 15:17:00.726071: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08240400 of size 2816 next 45
# 2024-12-31 15:17:00.726075: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08240f00 of size 16384 next 44
# 2024-12-31 15:17:00.726079: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08244f00 of size 16384 next 48
# 2024-12-31 15:17:00.726082: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08248f00 of size 16384 next 50
# 2024-12-31 15:17:00.726086: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0824cf00 of size 16384 next 52
# 2024-12-31 15:17:00.726089: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08250f00 of size 16384 next 54
# 2024-12-31 15:17:00.726092: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08254f00 of size 16384 next 58
# 2024-12-31 15:17:00.726096: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08258f00 of size 16384 next 60
# 2024-12-31 15:17:00.726099: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0825cf00 of size 16384 next 64
# 2024-12-31 15:17:00.726102: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08260f00 of size 16384 next 66
# 2024-12-31 15:17:00.726105: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08264f00 of size 16384 next 68
# 2024-12-31 15:17:00.726109: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08268f00 of size 16384 next 67
# 2024-12-31 15:17:00.726112: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0826cf00 of size 16384 next 70
# 2024-12-31 15:17:00.726115: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08270f00 of size 16384 next 74
# 2024-12-31 15:17:00.726119: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08274f00 of size 16384 next 76
# 2024-12-31 15:17:00.726122: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08278f00 of size 16384 next 95
# 2024-12-31 15:17:00.726125: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0827cf00 of size 16384 next 96
# 2024-12-31 15:17:00.726129: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08280f00 of size 2048 next 97
# 2024-12-31 15:17:00.726132: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08281700 of size 16384 next 98
# 2024-12-31 15:17:00.726135: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08285700 of size 16384 next 99
# 2024-12-31 15:17:00.726139: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08289700 of size 2048 next 100
# 2024-12-31 15:17:00.726142: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08289f00 of size 2048 next 101
# 2024-12-31 15:17:00.726145: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0828a700 of size 16384 next 102
# 2024-12-31 15:17:00.726148: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0828e700 of size 16384 next 103
# 2024-12-31 15:17:00.726152: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08292700 of size 256 next 104
# 2024-12-31 15:17:00.726155: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08292800 of size 256 next 105
# 2024-12-31 15:17:00.726158: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08292900 of size 256 next 106
# 2024-12-31 15:17:00.726162: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08292a00 of size 256 next 107
# 2024-12-31 15:17:00.726165: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08292b00 of size 256 next 108
# 2024-12-31 15:17:00.726168: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08292c00 of size 256 next 109
# 2024-12-31 15:17:00.726172: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08292d00 of size 16384 next 110
# 2024-12-31 15:17:00.726175: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08296d00 of size 16384 next 111
# 2024-12-31 15:17:00.726178: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0829ad00 of size 2048 next 112
# 2024-12-31 15:17:00.726182: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0829b500 of size 2048 next 113
# 2024-12-31 15:17:00.726185: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0829bd00 of size 16384 next 114
# 2024-12-31 15:17:00.726189: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0829fd00 of size 16384 next 115
# 2024-12-31 15:17:00.726192: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082a3d00 of size 256 next 116
# 2024-12-31 15:17:00.726195: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082a3e00 of size 256 next 117
# 2024-12-31 15:17:00.726198: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082a3f00 of size 256 next 118
# 2024-12-31 15:17:00.726202: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082a4000 of size 256 next 119
# 2024-12-31 15:17:00.726205: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082a4100 of size 256 next 120
# 2024-12-31 15:17:00.726208: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082a4200 of size 256 next 121
# 2024-12-31 15:17:00.726212: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082a4300 of size 16384 next 122
# 2024-12-31 15:17:00.726215: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082a8300 of size 16384 next 123
# 2024-12-31 15:17:00.726218: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082ac300 of size 2048 next 124
# 2024-12-31 15:17:00.726222: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082acb00 of size 2048 next 125
# 2024-12-31 15:17:00.726225: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082ad300 of size 16384 next 126
# 2024-12-31 15:17:00.726228: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082b1300 of size 16384 next 127
# 2024-12-31 15:17:00.726232: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082b5300 of size 2048 next 128
# 2024-12-31 15:17:00.726235: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082b5b00 of size 2048 next 129
# 2024-12-31 15:17:00.726238: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082b6300 of size 16384 next 130
# 2024-12-31 15:17:00.726242: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082ba300 of size 16384 next 131
# 2024-12-31 15:17:00.726245: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082be300 of size 2048 next 132
# 2024-12-31 15:17:00.726248: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082beb00 of size 2048 next 133
# 2024-12-31 15:17:00.726252: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082bf300 of size 16384 next 134
# 2024-12-31 15:17:00.726255: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082c3300 of size 16384 next 135
# 2024-12-31 15:17:00.726258: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082c7300 of size 256 next 136
# 2024-12-31 15:17:00.726262: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082c7400 of size 256 next 137
# 2024-12-31 15:17:00.726265: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082c7500 of size 256 next 138
# 2024-12-31 15:17:00.726268: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082c7600 of size 256 next 139
# 2024-12-31 15:17:00.726271: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082c7700 of size 256 next 140
# 2024-12-31 15:17:00.726275: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082c7800 of size 256 next 141
# 2024-12-31 15:17:00.726278: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082c7900 of size 16384 next 142
# 2024-12-31 15:17:00.726281: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082cb900 of size 16384 next 143
# 2024-12-31 15:17:00.726285: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082cf900 of size 2048 next 144
# 2024-12-31 15:17:00.726288: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d0100 of size 2048 next 145
# 2024-12-31 15:17:00.726292: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d0900 of size 16384 next 146
# 2024-12-31 15:17:00.726295: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d4900 of size 16384 next 147
# 2024-12-31 15:17:00.726298: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d8900 of size 256 next 148
# 2024-12-31 15:17:00.726302: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d8a00 of size 256 next 149
# 2024-12-31 15:17:00.726305: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d8b00 of size 256 next 150
# 2024-12-31 15:17:00.726308: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d8c00 of size 256 next 151
# 2024-12-31 15:17:00.726312: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d8d00 of size 256 next 152
# 2024-12-31 15:17:00.726315: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d8e00 of size 256 next 153
# 2024-12-31 15:17:00.726318: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082d8f00 of size 16384 next 154
# 2024-12-31 15:17:00.726321: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082dcf00 of size 16384 next 155
# 2024-12-31 15:17:00.726325: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082e0f00 of size 2048 next 156
# 2024-12-31 15:17:00.726328: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082e1700 of size 2048 next 157
# 2024-12-31 15:17:00.726332: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082e1f00 of size 16384 next 158
# 2024-12-31 15:17:00.726335: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082e5f00 of size 16384 next 159
# 2024-12-31 15:17:00.726338: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082e9f00 of size 2048 next 160
# 2024-12-31 15:17:00.726341: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082ea700 of size 2048 next 161
# 2024-12-31 15:17:00.726345: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082eaf00 of size 16384 next 162
# 2024-12-31 15:17:00.726348: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082eef00 of size 16384 next 163
# 2024-12-31 15:17:00.726352: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082f2f00 of size 2048 next 164
# 2024-12-31 15:17:00.726355: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082f3700 of size 2048 next 165
# 2024-12-31 15:17:00.726358: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082f3f00 of size 16384 next 166
# 2024-12-31 15:17:00.726362: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082f7f00 of size 16384 next 167
# 2024-12-31 15:17:00.726365: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082fbf00 of size 256 next 168
# 2024-12-31 15:17:00.726368: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082fc000 of size 256 next 169
# 2024-12-31 15:17:00.726371: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082fc100 of size 256 next 170
# 2024-12-31 15:17:00.726375: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082fc200 of size 256 next 171
# 2024-12-31 15:17:00.726378: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082fc300 of size 256 next 172
# 2024-12-31 15:17:00.726381: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082fc400 of size 256 next 173
# 2024-12-31 15:17:00.726385: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b082fc500 of size 16384 next 174
# 2024-12-31 15:17:00.726388: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08300500 of size 16384 next 175
# 2024-12-31 15:17:00.726392: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08304500 of size 2048 next 176
# 2024-12-31 15:17:00.726395: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08304d00 of size 2048 next 177
# 2024-12-31 15:17:00.726398: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08305500 of size 16384 next 178
# 2024-12-31 15:17:00.726402: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08309500 of size 16384 next 179
# 2024-12-31 15:17:00.726405: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0830d500 of size 256 next 180
# 2024-12-31 15:17:00.726408: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0830d600 of size 256 next 181
# 2024-12-31 15:17:00.726412: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0830d700 of size 256 next 182
# 2024-12-31 15:17:00.726415: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0830d800 of size 256 next 183
# 2024-12-31 15:17:00.726418: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0830d900 of size 256 next 184
# 2024-12-31 15:17:00.726422: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0830da00 of size 256 next 185
# 2024-12-31 15:17:00.726425: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0830db00 of size 16384 next 186
# 2024-12-31 15:17:00.726428: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08311b00 of size 16384 next 187
# 2024-12-31 15:17:00.726432: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08315b00 of size 2048 next 188
# 2024-12-31 15:17:00.726435: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08316300 of size 2048 next 189
# 2024-12-31 15:17:00.726438: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08316b00 of size 16384 next 190
# 2024-12-31 15:17:00.726442: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0831ab00 of size 16384 next 191
# 2024-12-31 15:17:00.726445: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0831eb00 of size 2048 next 192
# 2024-12-31 15:17:00.726448: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0831f300 of size 2048 next 193
# 2024-12-31 15:17:00.726452: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0831fb00 of size 16384 next 194
# 2024-12-31 15:17:00.726455: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08323b00 of size 16384 next 195
# 2024-12-31 15:17:00.726458: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08327b00 of size 2048 next 196
# 2024-12-31 15:17:00.726462: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08328300 of size 2048 next 197
# 2024-12-31 15:17:00.726465: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08328b00 of size 16384 next 198
# 2024-12-31 15:17:00.726468: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0832cb00 of size 16384 next 199
# 2024-12-31 15:17:00.726472: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08330b00 of size 256 next 200
# 2024-12-31 15:17:00.726475: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08330c00 of size 256 next 201
# 2024-12-31 15:17:00.726478: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08330d00 of size 256 next 202
# 2024-12-31 15:17:00.726482: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08330e00 of size 256 next 203
# 2024-12-31 15:17:00.726485: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08330f00 of size 256 next 204
# 2024-12-31 15:17:00.726488: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08331000 of size 256 next 205
# 2024-12-31 15:17:00.726491: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08331100 of size 16384 next 206
# 2024-12-31 15:17:00.726495: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08335100 of size 16384 next 207
# 2024-12-31 15:17:00.726498: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08339100 of size 2048 next 208
# 2024-12-31 15:17:00.726501: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08339900 of size 2048 next 209
# 2024-12-31 15:17:00.726505: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0833a100 of size 16384 next 210
# 2024-12-31 15:17:00.726508: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0833e100 of size 16384 next 211
# 2024-12-31 15:17:00.726512: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342100 of size 256 next 212
# 2024-12-31 15:17:00.726515: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342200 of size 256 next 213
# 2024-12-31 15:17:00.726519: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342300 of size 256 next 214
# 2024-12-31 15:17:00.726522: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342400 of size 256 next 215
# 2024-12-31 15:17:00.726525: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342500 of size 256 next 216
# 2024-12-31 15:17:00.726528: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342600 of size 256 next 217
# 2024-12-31 15:17:00.726532: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342700 of size 256 next 218
# 2024-12-31 15:17:00.726535: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342800 of size 256 next 219
# 2024-12-31 15:17:00.726538: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342900 of size 256 next 220
# 2024-12-31 15:17:00.726542: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342a00 of size 256 next 221
# 2024-12-31 15:17:00.726545: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342b00 of size 256 next 222
# 2024-12-31 15:17:00.726548: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342c00 of size 256 next 223
# 2024-12-31 15:17:00.726552: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342d00 of size 256 next 224
# 2024-12-31 15:17:00.726555: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342e00 of size 256 next 225
# 2024-12-31 15:17:00.726558: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08342f00 of size 256 next 226
# 2024-12-31 15:17:00.726562: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08343000 of size 256 next 227
# 2024-12-31 15:17:00.726565: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08343100 of size 256 next 228
# 2024-12-31 15:17:00.726568: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08343200 of size 256 next 229
# 2024-12-31 15:17:00.726572: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b08343300 of size 1024000 next 230
# 2024-12-31 15:17:00.726576: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0843d300 of size 256 next 233
# 2024-12-31 15:17:00.726579: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at b0843d400 of size 256 next 234
# 2024-12-31 15:17:00.726583: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0843d500 of size 256 next 235
# 2024-12-31 15:17:00.726586: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0843d600 of size 256 next 236
# 2024-12-31 15:17:00.726589: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0843d700 of size 256 next 237
# 2024-12-31 15:17:00.726593: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at b0843d800 of size 512 next 239
# 2024-12-31 15:17:00.726596: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b0843da00 of size 256 next 240
# ...
# 2024-12-31 15:17:00.726657: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b1bfab300 of size 65536000 next 247
# 2024-12-31 15:17:00.726661: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b1fe2b300 of size 1024000 next 255
# 2024-12-31 15:17:00.726665: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b1ff25300 of size 1024000 next 257
# 2024-12-31 15:17:00.726669: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2001f300 of size 128000 next 258
# 2024-12-31 15:17:00.726673: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2003e700 of size 128000 next 259
# 2024-12-31 15:17:00.726676: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2005db00 of size 128000 next 260
# 2024-12-31 15:17:00.726680: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2007cf00 of size 1024000 next 256
# 2024-12-31 15:17:00.726684: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b20176f00 of size 65536000 next 261
# 2024-12-31 15:17:00.726688: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b23ff6f00 of size 65536000 next 262
# 2024-12-31 15:17:00.726692: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b27e76f00 of size 65536000 next 263
# 2024-12-31 15:17:00.726695: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2bcf6f00 of size 1024000 next 264
# 2024-12-31 15:17:00.726699: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2bdf0f00 of size 1024000 next 270
# 2024-12-31 15:17:00.726703: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2beeaf00 of size 128000 next 271
# 2024-12-31 15:17:00.726707: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2bf0a300 of size 128000 next 272
# 2024-12-31 15:17:00.726711: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2bf29700 of size 128000 next 273
# 2024-12-31 15:17:00.726715: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2bf48b00 of size 1024000 next 269
# 2024-12-31 15:17:00.726719: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b2c042b00 of size 127616000 next 265
# 2024-12-31 15:17:00.726723: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b339f6f00 of size 65536000 next 268
# 2024-12-31 15:17:00.726727: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b37876f00 of size 1024000 next 274
# 2024-12-31 15:17:00.726731: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b37970f00 of size 1024000 next 276
# 2024-12-31 15:17:00.726734: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at b37a6af00 of size 128000 next 277
# 2024-12-31 15:17:00.726738: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b37a8a300 of size 128000 next 278
# 2024-12-31 15:17:00.726742: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b37aa9700 of size 128000 next 279
# 2024-12-31 15:17:00.726746: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b37ac8b00 of size 1024000 next 275
# 2024-12-31 15:17:00.726750: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b37bc2b00 of size 65536000 next 280
# 2024-12-31 15:17:00.726753: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b3ba42b00 of size 65536000 next 281
# 2024-12-31 15:17:00.726757: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b3f8c2b00 of size 65536000 next 282
# 2024-12-31 15:17:00.726761: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at b43742b00 of size 361728000 next 238
# 2024-12-31 15:17:00.726765: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b5903b300 of size 1024000000 next 231
# 2024-12-31 15:17:00.726769: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at b960cb300 of size 1024000000 next 266
# 2024-12-31 15:17:00.726773: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at bd315b300 of size 1024000000 next 267
# 2024-12-31 15:17:00.726779: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at c101eb300 of size 1024000000 next 285
# 2024-12-31 15:17:00.726785: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at c4d27b300 of size 400051456 next 18446744073709551615
# 2024-12-31 15:17:00.726791: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2024-12-31 15:17:00.726798: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 113 Chunks of size 256 totalling 28.2KiB
# 2024-12-31 15:17:00.726805: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1280 totalling 1.2KiB
# 2024-12-31 15:17:00.726812: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 46 Chunks of size 2048 totalling 92.0KiB
# 2024-12-31 15:17:00.726817: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2816 totalling 2.8KiB
# 2024-12-31 15:17:00.726824: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3072 totalling 3.0KiB
# 2024-12-31 15:17:00.726830: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 71 Chunks of size 16384 totalling 1.11MiB
# 2024-12-31 15:17:00.726837: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 31488 totalling 30.8KiB
# 2024-12-31 15:17:00.726846: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 12 Chunks of size 128000 totalling 1.46MiB
# 2024-12-31 15:17:00.726854: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 14 Chunks of size 1024000 totalling 13.67MiB
# 2024-12-31 15:17:00.726861: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2045952 totalling 1.95MiB
# 2024-12-31 15:17:00.726869: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 11 Chunks of size 65536000 totalling 687.50MiB
# 2024-12-31 15:17:00.726877: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 127232000 totalling 121.34MiB
# 2024-12-31 15:17:00.726884: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 127616000 totalling 121.70MiB
# 2024-12-31 15:17:00.726889: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 1024000000 totalling 3.81GiB
# 2024-12-31 15:17:00.726893: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 4.74GiB
# 2024-12-31 15:17:00.726899: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 5853151232 memory_limit_: 5853151232 available bytes: 0 curr_region_allocation_bytes_: 11706302464
# 2024-12-31 15:17:00.726908: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      5853151232
# InUse:                      5090987008
# MaxInUse:                   5222059008
# NumAllocs:                         473
# MaxAllocSize:               1155072000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-12-31 15:17:00.726921: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] ******************_____***********************************************************************______
# 2024-12-31 15:17:00.726956: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at softmax_op_gpu.cu.cc:203 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,8,1000,1000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[7], line 24
#      22 # Train diffusion model
#      23 print("Training diffusion model...")
# ---> 24 diffusion_history = diffusion_model.fit(
#      25     X_train_enc, Y_train_enc,
#      26     validation_data=(X_valid_enc, Y_valid_enc),
#      27     epochs=50,
#      28     batch_size=32,
#      29     verbose=1
#      30 )
#      32 # Save diffusion model
#      33 diffusion_final_path = os.path.join(diffusion_output_dir, 'diffusion_model_taweel_final.h5')
#
# File ~/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node DiffusionModel/multi_head_attention_2/softmax/Softmax defined at (most recent call last):
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/runpy.py", line 87, in _run_code
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/asyncio/events.py", line 80, in _run
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#
#   File "/tmp/ipykernel_939/809680305.py", line 24, in <module>
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/training.py", line 1150, in train_step
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/layers/attention/multi_head_attention.py", line 600, in call
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/layers/attention/multi_head_attention.py", line 533, in _compute_attention
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/layers/attention/multi_head_attention.py", line 499, in _masked_softmax
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/layers/activation/softmax.py", line 107, in call
#
#   File "/home/tarek/miniconda3/envs/baytdiffuser_env/lib/python3.9/site-packages/keras/src/backend.py", line 5448, in softmax
#
# OOM when allocating tensor with shape[32,8,1000,1000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node DiffusionModel/multi_head_attention_2/softmax/Softmax}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_9258]

# %%
# =============================================================================
# Transformer Model
# =============================================================================

transformer_model_name = 'aubmindlab/bert-base-arabertv2'
max_length = 1000

print("Creating transformer model...")
transformer_model, tokenizer = create_transformer_model(transformer_model_name, max_length)

train_texts = train_subset['text'].tolist()
valid_texts = valid_subset['text'].tolist()

# Train transformer model
print("Training transformer model...")
transformer_history = train_transformer_model(
    model=transformer_model,
    tokenizer=tokenizer,
    train_data=train_subset.to_dict('records'),
    valid_data=valid_subset.to_dict('records'),
    epochs=50,
    batch_size=16,
    output_dir=transformer_output_dir,
    max_length=max_length
)

# Save transformer model
transformer_final_path = os.path.join(transformer_output_dir, 'transformer_model_taweel_final.h5')
transformer_model.save(transformer_final_path)
print(f"Transformer model saved to {transformer_final_path}")

# Save tokenizer
tokenizer_final_path = os.path.join(transformer_output_dir, 'tokenizer_taweel_final.json')
tokenizer.save_pretrained(transformer_output_dir)
print(f"Tokenizer saved to {tokenizer_final_path}")

# %%
# Save diffusion model
diffusion_final_path = os.path.join(diffusion_output_dir, 'diffusion_model_test_final.h5')
diffusion_model.save(diffusion_final_path)
print(f"Diffusion model saved to {diffusion_final_path}")

# Save transformer model
transformer_final_path = os.path.join(transformer_output_dir, 'transformer_model_test_final.h5')
transformer_model.save(transformer_final_path)
print(f"Transformer model saved to {transformer_final_path}")

# %%
# =============================================================================
# Plot Training Histories
# =============================================================================

# Diffusion Model
plt.figure(figsize=(12, 6))
plt.plot(diffusion_history.history['loss'], label='Train Loss')
plt.plot(diffusion_history.history['val_loss'], label='Validation Loss')
plt.title('Diffusion Model Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Transformer Model
plt.figure(figsize=(12, 6))
plt.plot(transformer_history.history['loss'], label='Train Loss')
plt.plot(transformer_history.history['val_loss'], label='Validation Loss')
plt.title('Transformer Model Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
